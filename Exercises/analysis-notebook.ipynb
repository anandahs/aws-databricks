# %%
from data_helpers import *

# %%
config = get_pipeline_config("development")
print("Pipeline configuration:")
for key, value in config.items():
    print(f"  {key}: {value}")

# %%
log_pipeline_step("Filter: Premium cut only", input_count=53940, output_count=13791)

# Format some numbers for display
revenue = 4_352_761.50
print(f"\nTotal revenue: {format_number(revenue, prefix='$')}")
print(f"Average price: {format_number(revenue / 13791, prefix='$')}")
