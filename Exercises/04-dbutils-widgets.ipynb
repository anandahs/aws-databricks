# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls("/databricks-datasets")

for file in files:
    print(f"{file.name:<40} {file.size:>10} bytes")

# %%
dbutils.fs.mkdirs("/Workspace/Shared/Config")

config_content = """
env=development
raw_path=raw_data_path
silver_path=silver_data_path
gold_path=gold_data_path
"""

dbutils.fs.put("/Workspace/Shared/Config/application.conf", config_content, True)

# %%
dbutils.fs.rm("/Workspace/Shared/Config", True)

# %%
result = dbutils.notebook.run("./05-row-counter", 120, 
                     {"file_path_value": "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv"})

print(f"Result: {result}")
