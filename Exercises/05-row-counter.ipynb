# %%
dbutils.widgets.text("file_path_value", "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv", "Provide your file path")

file_path = dbutils.widgets.get("file_path_value")
print(f"Got input: {file_path}")

# %%
df = ( spark.read
      .option("header", "true")
      .option("inferSchema", "true")
      .csv(file_path)
)

row_count = df.count()
print(f"Row count: {row_count}")

dbutils.notebook.exit(row_count)
